# %%
from utils import plot_bidirectional_heatmaps, get_matrices, load_results

# %% [markdown]
# ## UMLIPs recontruction errors on MAD

# %%
import os

base = "../results/reconstruction_errors/umlips"

results_gfre_bb = load_results(os.path.join(base, "gfre_mad.json"))
results_lfre_bb = load_results(os.path.join(base, "lfre_mad.json"))

error_matrix_gfre, annot_matrix_gfre = get_matrices(results_gfre_bb)
error_matrix_lfre, annot_matrix_lfre = get_matrices(results_lfre_bb)

plot_bidirectional_heatmaps(
    error_matrix_gfre, annot_matrix_gfre,
    error_matrix_lfre, annot_matrix_lfre,
    title1="GFRE",
    title2="LFRE",
    cbar_label="GFRE or LFRE",
    save_path="../results/figures/umlips/errors_mad.png",
    rotate_ticks=True
)

# %% [markdown]
# ## UMLIPs recontruction errors on Alexandria

# %%
import os

base = "../results/reconstruction_errors/umlips"

results_gfre_bb = load_results(os.path.join(base, "gfre_alexandria.json"))
results_lfre_bb = load_results(os.path.join(base, "lfre_alexandria.json"))

error_matrix_gfre, annot_matrix_gfre = get_matrices(results_gfre_bb)
error_matrix_lfre, annot_matrix_lfre = get_matrices(results_lfre_bb)

plot_bidirectional_heatmaps(
    error_matrix_gfre, annot_matrix_gfre,
    error_matrix_lfre, annot_matrix_lfre,
    title1="GFRE",
    title2="LFRE",
    cbar_label="GFRE or LFRE",
    save_path="../results/figures/umlips/errors_alexandria.png",
    rotate_ticks=True
)

# %% [markdown]
# ## UMLIPs cumulant-based recontruction errors on MAD

# %%
import os

base = "../results/reconstruction_errors/cumulants"

results_gfre_bb = load_results(os.path.join(base, "gfre_umlips.json"))
results_lfre_bb = load_results(os.path.join(base, "lfre_umlips.json"))

error_matrix_gfre, annot_matrix_gfre = get_matrices(results_gfre_bb)
error_matrix_lfre, annot_matrix_lfre = get_matrices(results_lfre_bb)

plot_bidirectional_heatmaps(
    error_matrix_gfre, annot_matrix_gfre,
    error_matrix_lfre, annot_matrix_lfre,
    title1="GFRE",
    title2="LFRE",
    cbar_label="GFRE or LFRE",
    save_path="../results/figures/cumulants/errors_mad_umlips.png",
    rotate_ticks=True
)

# %% [markdown]
# ## UMLIPs backbone features recontruction errors on MAD

# %%
import os

base = "../results/reconstruction_errors/umlips"

results_gfre_bb = load_results(os.path.join(base, "gfre_mad_bb.json"))
results_lfre_bb = load_results(os.path.join(base, "lfre_mad_bb.json"))

error_matrix_gfre, annot_matrix_gfre = get_matrices(results_gfre_bb)
error_matrix_lfre, annot_matrix_lfre = get_matrices(results_lfre_bb)

plot_bidirectional_heatmaps(
    error_matrix_gfre, annot_matrix_gfre,
    error_matrix_lfre, annot_matrix_lfre,
    title1="GFRE",
    title2="LFRE",
    cbar_label="GFRE or LFRE",
    save_path="../results/figures/umlips/errors_mad_bb.png",
    rotate_ticks=True
)
